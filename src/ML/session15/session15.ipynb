# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split

# %%
plt.figure(figsize=(3,3))
sns.pairplot(data, x_vars=['YearsExperience'],y_vars=['Salary'],size = 3, kind= "scatter")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 plt.figure(figsize=(3,3))
# ----> 2 sns.pairplot(data, x_vars=['YearsExperience'],y_vars=['Salary'],size = 3, kind= "scatter")
#       3
#
# NameError: name 'data' is not defined

# %%
x = data.iloc[:,:-1]
y = data.iloc[:,1]
 
x_train, x_test, y_train, y_test  = train_test_split(x,y, train_size=0.8,random_state=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x = data.iloc[:,:-1]
#       2 y = data.iloc[:,1]
#       3
#       4 x_train, x_test, y_train, y_test  = train_test_split(x,y, train_size=0.8,random_state=50)
#
# NameError: name 'data' is not defined

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
y_hat = lin_reg.predict(x_train)

# %%
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, y_hat_train, color = 'blue')
plt.title("Salary vs Experience of years")
plt.xlabel("years")
plt.ylabel("Salary")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.scatter(x_train, y_train, color = 'red')
#       2 plt.plot(x_train, y_hat_train, color = 'blue')
#       3 plt.title("Salary vs Experience of years")
#       4 plt.xlabel("years")
#
# NameError: name 'x_train' is not defined

# %%
import tkinter as tk
import numpy as np
 
class SalaryPredictionApp:
    def __init__(self,root) -> None:
        self.root = root
        self.root.title("Dep for machine learning")
        self.root.geometry("500x400")
       
       
       
       
if __name__ == "__main__":
    root = tk.Tk()
    app = SalaryPredictionApp(root)
    root.mainloop()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
#%%
import warnings
warnings.filterwarnings('ignore')
 
# %matplotlib inline

# %%
data = pd.read_csv(r"Salary_Data.csv") # real
data.tail()
data.info()
data.describe()
def readdata():
    pass
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
#%%
# cooking the data
X = data.iloc[:,:-1]
y = data.iloc[:,1]
 
X_train , X_test , y_train , y_test = train_test_split(X,y,train_size=0.8,random_state = 10)

# %%
from sklearn.preprocessing import PolynomialFeatures
 
poly = PolynomialFeatures(degree=3)  
X_poly_train = poly.fit_transform(X_train)
 
X_poly_test = poly.transform(X_test)
 
poly_model = LinearRegression()
poly_model.fit(X_poly_train, y_train)
 
y_poly_pred_train = poly_model.predict(X_poly_train)
y_poly_pred_test = poly_model.predict(X_poly_test)
 
 
 
X_range = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
X_range_poly = poly.transform(X_range)
y_range_pred = poly_model.predict(X_range_poly)

# %%
my_model = LinearRegression()
my_model.fit(X_train,y_train)
#%%
plt.scatter(X_train, y_train, color = 'red')
plt.scatter(X_test, y_test, color='green', label='Test data')
plt.plot(X_train, my_model.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
 
 
plt.scatter(X_train, y_train, color='red', label='Training data')
plt.scatter(X_test, y_test, color='green', label='Test data')
plt.plot(X_range, y_range_pred, color='blue', label='Polynomial Regression')
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()

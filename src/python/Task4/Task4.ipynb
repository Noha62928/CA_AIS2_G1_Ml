# %%
class multiplication:
   """
   Task 1 : inputs a number and prints the multiplication table 
 
   """
   def __init__(self, num) -> None:
    self.num = num
   def multiplication_table(self):
     for i in range(1, 13):
             multiplication = self.num * i 
             print(f"{self.num} * {i} = {multiplication}")
     return

# %%
"""
Enter a number
"""
num = int(input("Please enter a number!"))
"""
create an object 
"""
m1 = multiplication(num)
m1.multiplication_table()
# Out:
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81
# 9 * 10 = 90
# 9 * 11 = 99
# 9 * 12 = 108

# %%
class Task2:
    """
    Print two primes less than 1000
    """
    def __init__(self, limit) -> None:
        self.num = 1000
    def twin_primes(self):
        print("Twin Prime: ")
        for n in range(0, self.num):
                if n % 2 != 0:
                    prime1 = True
                    for i in range(2, n):
                        if n % i == 0:
                            prime1 = False
                            break
                    prime2 = True
                    for i in range(2, n + 2):
                        if (n + 2) % i == 0:
                            prime2 = False
                            break
                    if prime1 == True and prime2 == True:
                        print(n, "and", n + 2)
        return

# %%
"""
Create an object 
"""
t1 = Task2(num)
t1.twin_primes()
# Out:
# Twin Prime:
# 1 and 3
# 3 and 5
# 5 and 7
# 11 and 13
# 17 and 19
# 29 and 31
# 41 and 43
# 59 and 61
# 71 and 73
# 101 and 103
# 107 and 109
# 137 and 139
# 149 and 151
# 179 and 181
# 191 and 193
# 197 and 199
# 227 and 229
# 239 and 241
# 269 and 271
# 281 and 283
# 311 and 313
# 347 and 349
# 419 and 421
# 431 and 433
# 461 and 463
# 521 and 523
# 569 and 571
# 599 and 601
# 617 and 619
# 641 and 643
# 659 and 661
# 809 and 811
# 821 and 823
# 827 and 829
# 857 and 859
# 881 and 883

# %%
class PrimeFactors:
    """
    This finds the prime factors of a number  
    """
    def __init__(self, num):
        self.num = num 
    def prime_factors(self):
        for i in range (2, self.num):
                while self.num%i == 0 : 
                    n = i 
                    self.num = self.num/i 
                    print(n)
        return

# %%
num = int(input("Please enter a number: "))
"""
Create an object   
"""
P1 = PrimeFactors(num)
"""
call the function  
"""
P1.prime_factors()
# Out:
# 2
# 2
# 2
# 7

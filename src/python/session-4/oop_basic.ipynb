# %%
"""
this class care about ...........
"""
class Student: 
    name = "Depi"
    age = 5 

    def std_info(self):
        print("hello depi students")

# %%
s1 = Student()
s1.name = "George"
s1.age = 39
print(s1.name)
print(s1.age)
s1
s1.std_info()
# Out:
# George
# 39
# hello depi students

# %%
class Student:
    def __init__(self, name, age) -> None: 
        self.name = name
        self.age = age 
    def std_info(self): 
        return f"my name is {self.name} and my age is {self.age}"

# %%
s1 = Student("Noha", 27)
s1.std_info()
# Out:
# 'my name is Noha and my age is 27'

# %%
"""
this class care about ...........
"""
class Student: 
    name = "Depi"
    age = 5 

    def std_info(self):
        print("hello depi students")

# %%
s1 = Student()
s1.name = "George"
s1.age = 39
print(s1.name)
print(s1.age)
s1
s1.std_info()
# Out:
# George
# 39
# hello depi students

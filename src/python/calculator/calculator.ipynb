# %%
def Addition (x, y):
    return(x+y)

def Subtraction (x, y):
    return(x-y)

def Multiplication (x, y):
    return(x*y)

def Division (x, y):
    return(x/y)

print(f"welcome to the simple calculator")
print(f"please select and operation")
print(f"1.Addition(+)")
print(f"2.Subtraction(-)")
print(f"3.Multiplication(*)")
print(f"4.Division(/)")
print(f"5.exit")
user_choice = input("Please enter your choice (1/2/3/4/5)")
if user_choice != "5": 
    x = float(input("PLease enter the first number : "))
    y = float(input("Please enter the second number : "))
    if user_choice == "1": 
        print (f"{x} + {y} = {Addition(x, y)}")
    elif user_choice == "2" : 
        print(f"{x} - {y} = {Subtraction(x, y)}")
    elif user_choice == "3": 
        print(f"{x} * {y} = {Multiplication(x, y)}")
    elif user_choice == "4" : 
        if y!= "0" : 
         print(f"{x} / {y} = {Division(x, y)}")
        elif y == "0" : 
         y = float(input("Error, Please enter a valid number !"))
                   

elif user_choice == "5" : 
        print(f"Thank you, exiting!")
# Out:
# welcome to the simple calculator
# please select and operation
# 1.Addition(+)
# 2.Subtraction(-)
# 3.Multiplication(*)
# 4.Division(/)
# 5.exit
# 10.0 / 2.0 = 5.0

# %%
def Addition (x, y):
    return(x+y)

def Subtraction (x, y):
    return(x-y)

def Multiplication (x, y):
    return(x*y)

def Division (x, y):
    return(x/y)

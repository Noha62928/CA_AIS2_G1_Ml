# %%
import numpy as np 
np.random.random((3,3))
# Out:
# array([[0.67907067, 0.38427354, 0.34656877],
#        [0.91366832, 0.26348086, 0.54226572],
#        [0.32134189, 0.53454224, 0.96715467]])

# %%
a = ["ali",3, "omar",False]
np.random.choice(a, size=(3, 5))
# Out:
# array([['3', 'False', 'False', 'omar', 'ali'],
#        ['3', 'False', 'ali', 'False', 'False'],
#        ['ali', 'omar', '3', 'False', 'False']], dtype='<U21')
